# %% [markdown]
# <a href="https://colab.research.google.com/github/bhattacharyyadebangana-blip/TESTING/blob/main/MBA_PYTHON_280126.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi

# %%
print("it's")
# Out:
# it's

# %% [markdown]
# ** Variable and data types** **bold text**

# %%
x=3
type(x)

int

# %%
s1 = 3.0
type(s1)
# Out:
# float

# %%
x3 = "3"
type(x3)
# Out:
# str

# %%
print("x3")
# Out:
# x3

# %%
s=int(3)
type(s)
# Out:
# int

# %%
s=float(3)
type(s)
# Out:
# float

# %%
print(s1)
# Out:
# 3.0

# %%
s2=str(3)
type(s2)
# Out:
# str

# %%
print(s2)
# Out:
# 3

# %%
a=3
type(a)
# Out:
# int

# %%
m1=float(a) #typecasting integer-a to float-m1
type(m1)
# Out:
# float

# %%
m1
# Out:
# 3.0

# %%
m2 = str(a) #typecasting integer-a to str-m2
type(m2)
# Out:
# str

# %%
str(m2)
# Out:
# '3'

# %%
a=5
b=7
print ("old a:",a)
a= a + b # first 5+7, then store the result (12) in a
print ("new a:",a)
# Out:
# old a: 5
# new a: 12
